# %% [markdown]
# Part 1: Project Overview & Data Loading
# **Students:**
#
#
#
# Problem Description:
# This project focuses on Network Intrusion Detection. We use Computer Vision to classify network traffic images into three categories: Benign, Type A (SMB Attack), and Type B (TCP SYN Flood).
#
# Algorithm:
# We implemented the KNN (K-Nearest Neighbors) algorithm from scratch. It was chosen because it effectively identifies patterns in image pixels by measuring the Euclidean distance between feature vectors.
#
# LLM Prompts:
#
# "How to load Kaggle datasets using kagglehub in Colab?"
#
# "How to manually split files into 80% train and 20% test sets?"
#
# "Implement a KNN class from scratch with train and predict functions."
#
# "How to perform image normalization and flattening?"

# %% [markdown]
# # Part 1: Project Overview & Data Loading
# **Students:**
#
# Name: Maor S | ID: 9282
# Name: Opal S | ID: 3390
# Name: Mai S | ID: 8025
#
# **Problem Description:**
# This project focuses on Network Intrusion Detection. We use Computer Vision to classify network traffic images into three categories: Benign, Type A (SMB Attack), and Type B (TCP SYN Flood).
#
# **Algorithm:**
# We implemented the KNN (K-Nearest Neighbors) algorithm from scratch. It was chosen because it effectively identifies patterns in image pixels by measuring the Euclidean distance between feature vectors.
#
# **LLM Prompts:**
#
# "How to load Kaggle datasets using kagglehub in Colab?"
#
# "How to manually split files into 80% train and 20% test sets?"
#
# "Implement a KNN class from scratch with train and predict functions."
#
# "How to perform image normalization and flattening?"

# %%
import os

def find_dataset():
    print("Searching for your images... (this might take 30 seconds)")
    # מחפש בכל התיקיות המערכת של קולאב
    for root, dirs, files in os.walk('/'):
        # מחפש תיקייה שמתחילה ב-n (כמו n034 שראינו קודם)
        if any(d.startswith('n0') for d in dirs):
            print(f"✅ מצאתי! הנתיב הוא: {root}")
            return root
    return None

sidd_path = find_dataset()

if sidd_path:
    print(f"Setting sidd_path to: {sidd_path}")
    print("Content sample:", os.listdir(sidd_path)[:5])
else:
    print("❌ לא מצאתי את התיקייה. בואי ננסה לבדוק בנתיב המקומי:")
    print("Local content:", os.listdir('/content'))
# Out:
# Searching for your images... (this might take 30 seconds)
# ❌ לא מצאתי את התיקייה. בואי ננסה לבדוק בנתיב המקומי:
# Local content: ['.config', 'sample_data']
